# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\shaya\Downloads\project 6\Diwali Sales Data.csv",encoding='unicode_escape')

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
# Clearnig null values from data set

df.drop(['Status','unnamed1'], axis=1, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (11239, 13)

# %%
df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
# Change data type of the amount in dataset
df['Amount']=df['Amount'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int64
# dtypes: int64(5), object(8)
# memory usage: 1.2+ MB

# %%
# Change the column name
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns={'Marital_Status':'Shadi'}, inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Shadi', 'State', 'Zone', 'Occupation', 'Product_Category', 'Orders',
#        'Amount'],
#       dtype='object')

# %%
# use of describe method on dataset

df.describe()
# Out:
#             User_ID           Age         Shadi        Orders        Amount
# count  1.123900e+04  11239.000000  11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357      0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866      0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000      0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000      0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000      0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000      1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000      1.000000      4.000000  23952.000000

# %%
# Exploratory Data Analysis 

# Create a countplot of gender

ax=sns.countplot(x='Gender',data=df ,hue='Gender')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
# Create a barplot of genders which one buy the most

df.head(1)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Shadi        State  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28      0  Maharashtra
#
#       Zone  Occupation Product_Category  Orders  Amount
# 0  Western  Healthcare             Auto       1   23952

# %%
sales_gen=df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

# %%
ax=sns.barplot(x='Gender',y='Amount',data=sales_gen,hue="Gender")
plt.show()

# %%
# Create a countplot of age Group

ax=sns.countplot(x='Age Group',data=df ,hue='Gender')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
# Create a barplot of Age Group which one buy the most

sales_age=df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

# %%
sns.barplot(x='Age Group' ,y='Amount', data=sales_age, hue='Age Group')
plt.show()

# %%
# Total numbers of orders form top 10 states
df.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Shadi           State  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28      0     Maharashtra
# 1  1000732     Kartik  P00110942      F     26-35   35      1  Andhra Pradesh
#
#        Zone  Occupation Product_Category  Orders  Amount
# 0   Western  Healthcare             Auto       1   23952
# 1  Southern        Govt             Auto       3   23934

# %%
state_sales=df.groupby(['State'] ,as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='State',y='Orders',data=state_sales ,hue='State')
plt.show()

# %%
# Total numbers of Amount/Sales form top 10 states
df.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Shadi           State  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28      0     Maharashtra
# 1  1000732     Kartik  P00110942      F     26-35   35      1  Andhra Pradesh
#
#        Zone  Occupation Product_Category  Orders  Amount
# 0   Western  Healthcare             Auto       1   23952
# 1  Southern        Govt             Auto       3   23934

# %%
state_sales_amount=df.groupby(['State'] ,as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='State',y='Amount',data=state_sales_amount ,hue='State')
plt.show()

# %%
# Create a countplot for Martial-status/Shadi    
# 0 for married and 1 for unmarried

df.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Shadi           State  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28      0     Maharashtra
# 1  1000732     Kartik  P00110942      F     26-35   35      1  Andhra Pradesh
#
#        Zone  Occupation Product_Category  Orders  Amount
# 0   Western  Healthcare             Auto       1   23952
# 1  Southern        Govt             Auto       3   23934

# %%
ax=sns.countplot(x='Shadi',data=df ,hue='Shadi')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
# Barplot accoriding to shopping

gen_sales=df.groupby(['Shadi','Gender'] ,as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

# %%
gen_sales
# Out:
#    Shadi Gender    Amount
# 0      0      F  43786646
# 2      1      F  30549207
# 1      0      M  18338738
# 3      1      M  13574538

# %%
sns.barplot(x='Shadi',y='Amount',data=gen_sales ,hue='Gender')
plt.show()

# %%
# Create a countplot for Occupation
plt.figure(figsize=(17,5))
ax=sns.countplot(x='Occupation',data=df ,hue='Occupation')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
# Create a barplot 
occ_sales=df.groupby(['Occupation'] ,as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
plt.figure(figsize=(17,5))
sns.barplot(x='Occupation',y='Amount',data=occ_sales,hue='Occupation')
plt.show()

# %%
# Create a countplot for Product_Category
plt.figure(figsize=(22,6))
ax=sns.countplot(x='Product_Category',data=df ,hue='Product_Category')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
# Create a barplot 
occ_sales=df.groupby(['Product_Category'] ,as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
plt.figure(figsize=(22,5))
sns.barplot(x='Product_Category',y='Amount',data=occ_sales,hue='Product_Category')
plt.show()

# %%
# Most selling products 
most_sales=df.groupby(['Product_ID'] ,as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
plt.figure(figsize=(20,5))
sns.barplot(x='Product_ID',y='Orders',data=most_sales,hue='Product_ID')
plt.show()
